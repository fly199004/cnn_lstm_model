# %%
from graphviz import Source

# DOT语言描述的CNN部分图
dot_graph = """
digraph CNN_Architecture {
    rankdir=LR;  // 设置图的排列方向为从左到右
    node [shape=box, style=filled, color="#8ecae6", fontname="Helvetica"];

    // 定义网络层
    input [label="Input Layer\n(Embedding)", fillcolor="#219ebc"];
    conv1 [label="Conv1D Layer\nKernel Size: 3x1", fillcolor="#ffb703"];
    pool1 [label="MaxPooling1D Layer", fillcolor="#fb8500"];
    conv2 [label="Conv1D Layer\nKernel Size: 4x1", fillcolor="#ffb703"];
    pool2 [label="MaxPooling1D Layer", fillcolor="#fb8500"];
    conv3 [label="Conv1D Layer\nKernel Size: 5x1", fillcolor="#ffb703"];
    pool3 [label="MaxPooling1D Layer", fillcolor="#fb8500"];
    concat [label="Concatenation Layer", fillcolor="#ffcad4"];

    // 连接网络层
    input -> conv1 -> pool1 -> concat;
    input -> conv2 -> pool2 -> concat;
    input -> conv3 -> pool3 -> concat;
}
"""

# 创建图形
src = Source(dot_graph)
src.render('CNN_Architecture', format='png', cleanup=True)
src

# %%
from graphviz import Source
from IPython.display import display

# DOT语言代码
dot_code = '''
digraph LSTM_Architecture {
    rankdir=LR;
    node [shape=box, style=filled, color="lightblue"];
    
    // 定义网络层
    input [label="Input Layer\n(Embedding)"];
    conv1 [label="Conv Layer\nKernel Size: 3x1"];
    pool1 [label="Max Pooling Layer"];
    conv2 [label="Conv Layer\nKernel Size: 4x1"];
    pool2 [label="Max Pooling Layer"];
    conv3 [label="Conv Layer\nKernel Size: 5x1"];
    pool3 [label="Max Pooling Layer"];
    concat [label="Concatenation Layer"];
    bi_lstm [label="Bidirectional LSTM\nUnits: 128"];
    output [label="Output Layer\n(Sigmoid Activation)"];

    // 连接网络层
    input -> conv1 -> pool1 -> concat;
    input -> conv2 -> pool2 -> concat;
    input -> conv3 -> pool3 -> concat;
    concat -> bi_lstm;
    bi_lstm -> output;
}
'''

# 创建Source对象并渲染图像
source = Source(dot_code, format="png")
source.render(filename='systemd-journald_workflow', view=True)

# 在Jupyter Notebook中显示生成的图像
display(source)

# %%
from graphviz import Source

# DOT语言描述的中文CNN部分图
dot_graph = """
digraph CNN_Architecture {
    rankdir=LR;  // 设置图的排列方向为从左到右
    node [shape=box, style=filled, color="#8ecae6", fontname="Helvetica"];

    // 定义网络层
    input [label="输入层\n(嵌入层)", fillcolor="#219ebc"];
    conv1 [label="卷积层\n卷积核大小: 3x1", fillcolor="#ffb703"];
    pool1 [label="最大池化层", fillcolor="#fb8500"];
    conv2 [label="卷积层\n卷积核大小: 4x1", fillcolor="#ffb703"];
    pool2 [label="最大池化层", fillcolor="#fb8500"];
    conv3 [label="卷积层\n卷积核大小: 5x1", fillcolor="#ffb703"];
    pool3 [label="最大池化层", fillcolor="#fb8500"];
    concat [label="拼接层", fillcolor="#ffcad4"];

    // 连接网络层
    input -> conv1 -> pool1 -> concat;
    input -> conv2 -> pool2 -> concat;
    input -> conv3 -> pool3 -> concat;
}
"""

# 创建图形
src = Source(dot_graph)
src.render('CNN_Architecture_CN', format='png', cleanup=True)
src

# %%
from graphviz import Source
from IPython.display import display

# DOT语言代码
dot_code = '''
digraph LSTM_Architecture {
    rankdir=LR;
    node [shape=box, style=filled, color="lightblue"];
    
    // 定义网络层
    input [label="输入层\n(内嵌)"];
    conv1 [label="卷积层\n核大小: 3x1"];
    pool1 [label="最大池化层"];
    conv2 [label="卷积层\n核大小: 4x1"];
    pool2 [label="最大池化层"];
    conv3 [label="卷积层\n核大小: 5x1"];
    pool3 [label="最大池化层"];
    concat [label="拼接层"];
    bi_lstm [label="双向LSTM\nUnits: 128"];
    output [label="输出层\n(Sigmoid 激活)"];

    // 连接网络层
    input -> conv1 -> pool1 -> concat;
    input -> conv2 -> pool2 -> concat;
    input -> conv3 -> pool3 -> concat;
    concat -> bi_lstm;
    bi_lstm -> output;
}
'''

# 创建Source对象并渲染图像
source = Source(dot_code, format="png")
source.render(filename='systemd-journald_workflow', view=True)

# 在Jupyter Notebook中显示生成的图像
display(source)

# %%
from graphviz import Source

# DOT语言描述的全连接层和输出层网络模型图
dot_graph = """
digraph FullyConnected_Output_Layer {
    rankdir=LR;  // 设置图的排列方向为从左到右
    node [shape=box, style=filled, color="#bebada", fontname="Helvetica"];

    // 定义网络层
    bi_lstm [label="双向LSTM层\n(128单元)", fillcolor="#b3de69"];
    dense_layer [label="全连接层\n(128神经元)", fillcolor="#fccde5"];
    dropout_layer [label="Dropout层\n(0.5)", fillcolor="#d9d9d9"];
    output_layer [label="输出层\n(Softmax)", fillcolor="#80b1d3"];

    // 连接网络层
    bi_lstm -> dense_layer;
    dense_layer -> dropout_layer;
    dropout_layer -> output_layer;
}
"""

# 创建图形
src = Source(dot_graph)
src.render('FullyConnected_Output_Architecture', format='png', cleanup=True)
src

# %%
from graphviz import Source

# DOT语言描述的完整CNN-LSTM网络模型图
dot_graph = """
digraph CNN_LSTM_Architecture {
    rankdir=TB;  // 设置图的排列方向为从上到下
    node [shape=box, style=filled, color="#8ecae6", fontname="Helvetica"];

    // 定义网络层
    input [label="输入层\n(嵌入层)", fillcolor="#219ebc"];
    conv1 [label="卷积层\n卷积核: 3x1", fillcolor="#ffb703"];
    pool1 [label="最大池化层", fillcolor="#fb8500"];
    conv2 [label="卷积层\n卷积核: 4x1", fillcolor="#ffb703"];
    pool2 [label="最大池化层", fillcolor="#fb8500"];
    conv3 [label="卷积层\n卷积核: 5x1", fillcolor="#ffb703"];
    pool3 [label="最大池化层", fillcolor="#fb8500"];
    concat [label="拼接层", fillcolor="#ffcad4"];
    bi_lstm [label="双向LSTM层\n(128单元)", fillcolor="#b3de69"];
    dense [label="全连接层\n(128神经元)", fillcolor="#fccde5"];
    dropout [label="Dropout层\n(0.5)", fillcolor="#d9d9d9"];
    output [label="输出层\n(Softmax)", fillcolor="#80b1d3"];

    // 连接网络层
    input -> conv1 -> pool1 -> concat;
    input -> conv2 -> pool2 -> concat;
    input -> conv3 -> pool3 -> concat;
    concat -> bi_lstm -> dense -> dropout -> output;
}
"""

# 创建图形
src = Source(dot_graph)
src.render('Complete_CNN_LSTM_Architecture', format='png', cleanup=True)
src

# %%
from graphviz import Source

# DOT语言描述的完整CNN-LSTM网络模型图
dot_graph = """
digraph CNNModel {
    rankdir=LR; // 设置从左到右的图布局
    node [shape=record]; // 定义节点形状为矩形

    input [label="输入层|{词向量}"];
    conv1 [label="卷积层|{卷积核: 3x1}"];
    pool1 [label="池化层|{最大池化}"];
    conv2 [label="卷积层|{卷积核: 4x1}"];
    pool2 [label="池化层|{最大池化}"];
    conv3 [label="卷积层|{卷积核: 5x1}"];
    pool3 [label="池化层|{最大池化}"];
    flatten [label="扁平化层"];
    fc [label="全连接层|{ReLU激活}"];
    dropout [label="Dropout层|{率: 0.5}"];
    output [label="输出层|{Softmax激活}"];

    input -> conv1 -> pool1 -> flatten;
    input -> conv2 -> pool2 -> flatten;
    input -> conv3 -> pool3 -> flatten;
    flatten -> fc -> dropout -> output;
}

"""

# 创建图形
src = Source(dot_graph)
src.render('Signle_CNNModel', format='png', cleanup=True)
src

# %%
from graphviz import Source

# DOT语言描述的完整CNN-LSTM网络模型图
dot_graph = """
digraph LSTMModel {
    rankdir=LR; // 设置从左到右的图布局
    node [shape=record]; // 定义节点形状为矩形

    input [label="输入层|{词向量}"];
    lstm [label="LSTM层|{单向/双向}"];
    fc1 [label="全连接层|{ReLU激活}"];
    dropout [label="Dropout层|{率: 0.5}"];
    output [label="输出层|{Softmax激活}"];

    input -> lstm -> fc1 -> dropout -> output;
}

"""

# 创建图形
src = Source(dot_graph)
src.render('Signle_LSTMModel', format='png', cleanup=True)
src

# %%
from graphviz import Source

# DOT语言描述的实验流程
dot_graph = """
digraph G {
    node [shape=box, style=filled, color=lightblue];
    rankdir=TB; // 从上到下的流向

    数据收集与清洗 [shape=ellipse, fillcolor=lightyellow]
    特征提取 [shape=ellipse, fillcolor=lightyellow]
    数据集划分与加载 [shape=ellipse, fillcolor=lightyellow]
    模型构建与训练 [shape=ellipse, fillcolor=lightyellow]
    性能评估与比较 [shape=ellipse, fillcolor=lightyellow]
    结果讨论 [shape=ellipse, fillcolor=lightyellow]

    数据收集与清洗 -> 特征提取
    特征提取 -> 数据集划分与加载
    数据集划分与加载 -> 模型构建与训练
    模型构建与训练 -> 性能评估与比较
    性能评估与比较 -> 结果讨论
}


"""

# 创建图形
src = Source(dot_graph)
src.render('process', format='png', cleanup=True)
src
